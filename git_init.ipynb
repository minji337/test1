# %%
from google.colab import drive
import os
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/claude/deploy")

# %%
# !git config --global user.name "storybite"
# !git config --global user.email "heyjin337@gmail.com"

# %%
# !git init

# %%
# !echo "# test" >> README.md

# %%
# !git add README.md

# %%
# !git commit -m "first commit"

# %%
# !git branch -M main

# %%
# !git remote set-url origin https://{userdata.get("GITHUB_TOKEN")}@github.com/minji337/claude-docent.git

# %%
# !git push -u origin main
